# %% [markdown]
# <a href="https://colab.research.google.com/github/taeheonkwon/python2/blob/main/Lecture2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Python Basics
#
# > ## Entering Expressions into the Interactive Shell

# %%
pi = 3.141592

# %%
pi // 3
# Out:
# 1.0

# %% [markdown]
# > ## The Integer, Floating-Point, and String Data Types
#
# ![스크린샷 2021-03-15 오후 12.49.43.png](data:image/png;base64,...)

# %% [markdown]
# The order of operations (also called precedence) of Python math operators is similar to that of mathematics.
#
# The ** operator is evaluated first; the *, /, //, and % operators are evaluated next, from left to right; and the + and - operators are evaluated last (also from left to right).
#
# You can use parentheses to override the usual precedence if you need to.
#
# Whitespace in between the operators and values doesn’t matter for Python (except for the indentation at the beginning of the line), but a single space is convention.

# %%
a = 12; b=1

# %%
a + b
# Out:
# 13

# %%
a - b
# Out:
# 11

# %%
a * b
# Out:
# 12

# %%
a / b
# Out:
# 12.0

# %%
a // b
# Out:
# 12

# %%
a % b
# Out:
# 0

# %% [markdown]
# **Write an equation with the values given: 10,9**

# %% [markdown]
# >## String Concatenation and Replication

# %%
'Python'+' program'
# Out:
# 'Python program'

# %%
'Python '*3
# Out:
# 'Python Python Python '

# %%
 'Alice' * 5.0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-43325524c797> in <module>()
# ----> 1 'Alice' * 5.0
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
'python' + 3.0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-02509015f81a> in <module>()
# ----> 1 'python' + 3.0
#
# TypeError: can only concatenate str (not "float") to str

# %%
a, b = 'Goodbye', 'python'

# %%
a, b = b, a

# %%
a + b
# Out:
# 'pythonGoodbye'

# %%
a * 3
# Out:
# 'GoodbyeGoodbyeGoodbye'

# %%
print(a+b); print(a*3)
# Out:
# pythonGoodbye
# pythonpythonpython

# %% [markdown]
# >## Assignment operators
#
# ![스크린샷 2021-03-15 오후 12.34.05.png](data:image/png;base64,...)

# %%
a = 3
b = 4
c = 5

c = a + b
print("Line 1 - Value of c is ", c)

c += a
print("Line 2 - Value of c is ", c)

c *= a
print("Line 3 - Value of c is ", c)

c /= a 
print("Line 4 - Value of c is ", c)

c  = 2
c %= a
print("Line 5 - Value of c is ", c)

c **= a
print("Line 6 - Value of c is ", c)

c //= a
print("Line 7 - Value of c is ", c)
# Out:
# Line 1 - Value of c is  7
# Line 2 - Value of c is  10
# Line 3 - Value of c is  30
# Line 4 - Value of c is  10.0
# Line 5 - Value of c is  2
# Line 6 - Value of c is  8
# Line 7 - Value of c is  2

# %% [markdown]
# >## Comment, print, input
#
# - Any text for the rest of the line following a hash mark (#) is part of a comment.
#
# - The print() function displays the string value inside its parentheses on the screen.
#
# - The input() function waits for the user to type some text on the keyboard and press ENTER.

# %%
# This program says hello and asks for my name.

print('Hello, world!')
print('What is your name?')    # ask for their name
myName = input()
print('It is good to meet you, ' + myName)
print('The length of your name is:')
print(len(myName))
print('What is your age?')    # ask for their age
myAge = input()
print('You will be ' + str(int(myAge) + 1) + ' in a year.')
# Out:
# Hello, world!
# What is your name?
# Kwon
# It is good to meet you, Kwon
# The length of your name is:
# 4
# What is your age?
# 23
# You will be 24 in a year.

# %% [markdown]
# >## Data Types
# >
# >![스크린샷 2021-03-15 오후 1.13.00.png](data:image/png;base64,...)

# %% [markdown]
# >## Bool
# Booleans represent one of two values: True or False.

# %%
print(10 > 9)
print(10 == 9)
print(10 < 9)
# Out:
# True
# False
# False

# %%
bool(1)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool([])
# Out:
# False

# %%
print(bool(2))
print(bool(""))
print(bool([[]]))
print(True+True, False+False)
print(bool(()))
# Out:
# True
# False
# True
# 2 0
# False

# %% [markdown]
# >## Sequential Data Types : Strings
# >Strings in python are surrounded by either single quotation marks, or double quotation marks.
# >
# >You can assign a multiline string to a variable by using three quotes
# >
# >str() - constructs a string from a wide variety of data types, including strings, integer literals and float literals

# %%
print("Hello")
print('Hello')
# Out:
# Hello
# Hello

# %%
number_1 = 200
print(type(number_1), number_1)
char_1 = str(number_1)
print(type(char_1), char_1)
# Out:
# <class 'int'> 200
# <class 'str'> 200

# %%
int('12')
# Out:
# 12

# %%
int(float('12.1'))
# Out:
# 12

# %%
sentence = type(number_1)

# %%
print(sentence)
# Out:
# <class 'int'>

# %%
sentence = 'pythona'

# %%
len(sentence)
# Out:
# 7

# %% [markdown]
# “Indexing” means referring to an element of an iterable by its position within the iterable.
#
# Notation: [k]
#
# Example
#
# Get the character at position 6 (remember that the first character has the position 0):

# %%
sentence[6]
# Out:
# 'a'

# %% [markdown]
# “Slicing” means getting a subset of elements from an iterable based on their indices.
#
# Notation: [start:stop:step]
#
# If all three start , stop and step are provided, it generates portion of sequence after index start till stop with increment of index step.
#
# Example
#
# Get the characters from position 3 to position 7 (not included):

# %%
sentence[3:7]
# Out:
# 'hona'

# %%
sentence[::2]
# Out:
# 'ptoa'

# %%
sentence[-1]
# Out:
# 'a'

# %%
sentence[:-1]
# Out:
# 'python'

# %%
sentence = 'pythons'
sentence[-1]
# Out:
# 's'

# %%
sentence[:-1]
# Out:
# 'python'

# %%
sentence[-2]
# Out:
# 'n'

# %%
sentence[-3]
# Out:
# 'o'

# %% [markdown]
# >## format()
# >The format() method allows you to format selected parts of a string.
# >
# >The format() method takes the passed arguments, formats them, and places them in the string where the placeholders {} are:

# %%
print(format(3.141592, '10.3f'))
print(format(3.141592, '20.4f'))
# Out:
#      3.142
#               3.1416

# %%
list_range = list(range(1,4))
list_range
# Out:
# [1, 2, 3]

# %%
import math
for k in range(1,4):
    print('first:  sqrt({0}) = {1}'.format(k, math.sqrt(k)))
    print('second: sqrt({0}) = {1:5.3f}'.format(k, math.sqrt(k)))
    print('third:  sqrt({origin_number}) = {result}'.format(result=math.sqrt(k), origin_number=k))
# Out:
# first:  sqrt(1) = 1.0
# second: sqrt(1) = 1.000
# third:  sqrt(1) = 1.0
# first:  sqrt(2) = 1.4142135623730951
# second: sqrt(2) = 1.414
# third:  sqrt(2) = 1.4142135623730951
# first:  sqrt(3) = 1.7320508075688772
# second: sqrt(3) = 1.732
# third:  sqrt(3) = 1.7320508075688772

# %% [markdown]
# > ## The len() Function
#
# The len() function returns the number of items in an object.
#
# When the object is a string, the len() function returns the number of characters in the string.

# %%
mylist = ["apple", "banana", "cherry"]
x = len(mylist)
print(x)
# Out:
# 3

# %%
mydict = {'apple':100, 'banana':200, 'cherry':300}
len(mydict)
# Out:
# 3

# %%
len('python programing')
# Out:
# 17

# %% [markdown]
# >## Lists
# >Lists are used to store multiple items in a single variable.
# >
# >Lists are one of 4 built-in data types in Python used to store collections of data, the other 3 are Tuple, Set, and Dictionary, all with different qualities and usage.
# >
# >Lists are created using square brackets.
# >
# >List is a collection which is ordered and changeable. Allows duplicate members.
# >
# >Constructor : list()

# %%
thislist = ["apple", 10, (11,21), {41:100}, {31,32,33}, [5, 6, 7]]
print(thislist)
# Out:
# ['apple', 10, (11, 21), {41: 100}, {32, 33, 31}, [5, 6, 7]]

# %%
len(thislist)
# Out:
# 6

# %%
thislist[1]=10000

# %%
thislist
# Out:
# ['apple', 10000, (11, 21), {41: 100}, {31, 32, 33}, [5, 6, 7]]

# %%
thislist[2][1]
# Out:
# 21

# %%
auto_list = list(range(10))

# %%
auto_list[::2]
# Out:
# [0, 2, 4, 6, 8]

# %% [markdown]
# >## Tuple
# >
# >Tuples are used to store multiple items in a single variable.
# >
# >Tuple is a collection which is ordered and unchangeable.
# >
# > Allows duplicate members.
# >
# >Tuples are written with round brackets.
# >
# > Constructor : tuple()

# %%
t = (1,2,3)
t
# Out:
# (1, 2, 3)

# %%
len(t)
# Out:
# 3

# %%
t[-1]
# Out:
# 3

# %%
t+t+t
# Out:
# (1, 2, 3, 1, 2, 3, 1, 2, 3)

# %%
t*3
# Out:
# (1, 2, 3, 1, 2, 3, 1, 2, 3)

# %%
3 in t
# Out:
# True

# %%
t[0]=100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-3382f43ca263> in <module>()
# ----> 1 t[0]=100
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# >## Dictionary
# >
# >Dictionaries are used to store data values in key:value pairs.
# >
# >Dictionary is a collection which is unordered and changeable. No duplicate members.
# >
# > Constructor : dict()

# %%
d = {'one':1, 'two':2, 'three':3}

# %%
d['one']
# Out:
# 1

# %%
d['four']=4
print(d)
# Out:
# {'one': 1, 'two': 2, 'three': 3, 'four': 4}

# %%
d['one']='하나'

# %%
print(d)
# Out:
# {'one': '하나', 'two': 2, 'three': 3, 'four': 4}

# %%
'one' in d
# Out:
# True

# %% [markdown]
# >## Sets
# >
# >Set is a collection which is unordered and unindexed. No duplicate members.
# >
# >Sets are written with curly brackets.
# >
# > Constructor : set()

# %%
s1 = {1,2,3,4,3,3}

# %%
s1
# Out:
# {1, 2, 3, 4}

# %%
type(s1)
# Out:
# set

# %%
s2 = set()
s2
# Out:
# set()

# %%
s2={4,5,6}

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s1.intersection(s2)
# Out:
# {4}

# %%
s1-s2
# Out:
# {1, 2, 3}

# %%
s1 | s2
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s1.add(5)
print(s1)
# Out:
# {1, 2, 3, 4, 5}

# %%
s1.discard(5)

# %%
s1
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# >## Conditions and If statements
# >Python supports the usual logical conditions from mathematics:
# >
# >Equals: a == b
# >
# >Not Equals: a != b
# >
# >Less than: a < b
# >
# >Less than or equal to: a <= b
# >
# >Greater than: a > b
# >
# >Greater than or equal to: a >= b
# >
# >These conditions can be used in several ways, most commonly in "if statements" and loops.
# >
# >An "if statement" is written by using the if keyword.

# %%
a = 33
b = 200
if b > a:
  print("b is greater than a")
# Out:
# b is greater than a

# %%
a = 33
b = 200
if b > a:
    print("b is greater than a") # you will get an error
# Out:
# b is greater than a

# %%
a = 33
b = 33
if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")
# Out:
# a and b are equal

# %%
a = 200
b = 33
if b > a:
  print("b is greater than a")
else:
  print("b is not greater than a")
# Out:
# b is not greater than a

# %%
a = 2
b = 330
print("A") if a > b else print("B")
# Out:
# B

# %%
a = 2000
b = 330
print("A") if a > b else print("B")
# Out:
# A

# %%
a = 200
b = 33
c = 500
if a > b and c > a:
  print("Both conditions are True")
# Out:
# Both conditions are True

# %%
a = 200
b = 33
c = 500
if a > b or a > c:
  print("At least one of the conditions is True")
# Out:
# At least one of the conditions is True

# %%
n = -2
if n > 0:
    print('Positive')
elif n < 0:
    print('Negative')
else:
    print('Zero')
# Out:
# Negative

# %%
x = 41

if x > 10:
  print("Above ten,")
  if x > 20:
    print("and also above 20!")
  else:
    print("but not above 20.")
# Out:
# Above ten,
# and also above 20!

# %%
a = 33
b = 200

if b > a:
  pass

# %%
a = 10
(a/2, a*2)[a>5]
# Out:
# 20
