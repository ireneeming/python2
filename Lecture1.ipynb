# %% [markdown]
# <a href="https://colab.research.google.com/github/taeheonkwon/python2/blob/main/Lecture1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 2. 파이썬 실행 환경
#
# - colab.research.google.com 사용을 추천
#
# - 윈도우에서 pycharm을 사용해도 무방
#
# - 맥북 이나 리눅스 머신에서는  python 3.8 이상 설치 (Anaconda 설치를 추천)
# - Jupyter, IPython(Interactive Python) 사용 가능

# %% [markdown]
# ##3. 코딩 기법
#
# - https://www.python.org/dev/peps/pep-0008/
#
# - http://pythonstudy.xyz/python/article/511-
#
# ### 실제 사용할 코딩 기법
#
# - 들여쓰기를 할 때 Tab 대신 공백(Space)을 사용한다. 특히 Python 3는 Tab과 공백을 혼용해서 사용하는 것을 허용하지 않는다. -> Tab 과 Space 중 하나만 쓰자
#
# - 함수, 변수, Attribute는 소문자로 단어 간은 밑줄(_)을 사용하여 연결한다.
#
# - 클래스는 단어 첫 문자마다 대문자를 써서 연결하는 CapWords 포맷으로 명명한다.

# %%
sample_data_list = [10,20,30,40,50]
for i in sample_data_list:
    print(i)
    print("error")

# %%
class CodingConventionExample():
    def __init__(self, name, rank):
        self.name = name
        self.rank = rank

CCE = CodingConventionExample(' BGmaster', 'dia')
print(CCE.name,CCE.rank)
# Out:
#  BGmaster dia

# %%
from google.colab import files
uploaded = files.upload() # 파일 업로드 기능 실행

'''
for fn in uploaded.keys(): # 업로드된 파일 정보 출력
    print('User uploaded file "{name}" with length {length} bytes'.format(
        name=fn, length=len(uploaded[fn])))
'''
# Out:
#      <input type="file" id="files-349a17a7-7184-4bbd-8e55-2fcac25a028c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-349a17a7-7184-4bbd-8e55-2fcac25a028c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# '\nfor fn in uploaded.keys(): # 업로드된 파일 정보 출력\n    print(\'User uploaded file "{name}" with length {length} bytes\'.format(\n        name=fn, length=len(uploaded[fn])))\n'

# %%
Image('./IndentationError.png')

# %% [markdown]
# ## 파이썬 도움말
#  - dir( ), help, ? 사용
#
#  - tab 키를 이용한 namespace 검색

# %%
data_dict = {'key':'value'}
# ?data_dict

# %%
data_dict.

# %%
help(data_dict)

# %%
dir(sample_data_list)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %% [markdown]
# ## 실습
#  1) Creating variables and assigning values

# %%
a = 1729
print (a)
# Out:
# 1729

# %% [markdown]
# 위 예제와 같이 정수, 실수, 문자, 문자열, Boolean 자료에 대해 직접 값을 대입하고 출력해본다.

# %% [markdown]
# 2) 네임스페이스 해보기

# %%
sample_data_list.

# %% [markdown]
# 네임스페이스 사용 예제 : sample_data_list.

# %% [markdown]
# 3) 줄자처럼 해보기

# %%
ruler1 = '1'
ruler2 = ruler1 + ' 2 ' + ruler1
ruler3 = ruler2 + ' 3 ' + ruler2
ruler4 = ruler3 + ' 4 ' + ruler3

print(ruler1)
print(ruler2)
print(ruler3)
print(ruler4)
# Out:
# 1
# 1 2 1
# 1 2 1 3 1 2 1
# 1 2 1 3 1 2 1 4 1 2 1 3 1 2 1

# %% [markdown]
# 4) + - * // % ** 연산 해서 출력해 보기
